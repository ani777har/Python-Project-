# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(f" null sum - show_id: {df.show_id.isnull().sum()}")
print(f" null sum - type: {df.type.isnull().sum()}")
print(f" null sum - title: {df.title.isnull().sum()}")
print(f" null sum - director: {df.director.isnull().sum()}")
print(f" null sum - cast: {df.cast.isnull().sum()}")
print(f" null sum - country: {df.country.isnull().sum()}")
print(f" null sum - date_added: {df.date_added.isnull().sum()}")
print(f" null sum - release_year: {df.release_year.isnull().sum()}")
print(f" null sum - rating: {df.rating.isnull().sum()}")
print(f" null sum - duration: {df.duration.isnull().sum()}")
print(f" null sum - listed_in: {df.listed_in.isnull().sum()}")
print(f" null sum - description: {df.description.isnull().sum()}")
# Out:
#  null sum - show_id: 0
#  null sum - type: 0
#  null sum - title: 0
#  null sum - director: 2634
#  null sum - cast: 825
#  null sum - country: 831
#  null sum - date_added: 10
#  null sum - release_year: 0
#  null sum - rating: 4
#  null sum - duration: 3
#  null sum - listed_in: 0
#  null sum - description: 0

# %%
df["country"].fillna("MISSING", inplace=True)
df["duration"].fillna("0 min", inplace=True)

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
print(f" count - show_id: {df.show_id.count()}")
print(f" count - type: {df.type.count()}")
print(f" count - title: {df.title.count()}")
print(f" count - director: {df.director.count()}")
print(f" count - cast: {df.cast.count()}")
print(f" count - country: {df.country.count()}")
print(f" count - date_added: {df.date_added.count()}")
print(f" count - release_year: {df.release_year.count()}")
print(f" count - rating: {df.rating.count()}")
print(f" count - duration: {df.duration.count()}")
print(f" count - listed_in: {df.listed_in.count()}")
print(f" count - description: {df.description.count()}")
# Out:
#  count - show_id: 8807
#  count - type: 8807
#  count - title: 8807
#  count - director: 6173
#  count - cast: 7982
#  count - country: 8807
#  count - date_added: 8797
#  count - release_year: 8807
#  count - rating: 8803
#  count - duration: 8807
#  count - listed_in: 8807
#  count - description: 8807

# %%
print(f" unique - show_id: {df.show_id.nunique()}")
print(f" unique - type: {df.type.nunique()}")
print(f" unique - title: {df.title.nunique()}")
print(f" unique - director: {df.director.nunique()}")
print(f" unique - cast: {df.cast.nunique()}")
print(f" unique - country: {df.country.nunique()}")
print(f" unique - date_added: {df.date_added.nunique()}")
print(f" unique - release_year: {df.release_year.nunique()}")
print(f" unique - rating: {df.rating.nunique()}")
print(f" unique - duration: {df.duration.nunique()}")
print(f" unique - listed_in: {df.listed_in.nunique()}")
print(f" unique - description: {df.description.nunique()}")
# Out:
#  unique - show_id: 8807
#  unique - type: 2
#  unique - title: 8807
#  unique - director: 4528
#  unique - cast: 7692
#  unique - country: 749
#  unique - date_added: 1767
#  unique - release_year: 74
#  unique - rating: 17
#  unique - duration: 221
#  unique - listed_in: 514
#  unique - description: 8775

# %%
print(f" dtype - show_id: {df.show_id.dtype}")
print(f" dtype - type: {df.type.dtype}")
print(f" dtype - title: {df.title.dtype}")
print(f" dtype - director: {df.director.dtype}")
print(f" dtype - cast: {df.cast.dtype}")
print(f" dtype - country: {df.country.dtype}")
print(f" dtype - date_added: {df.date_added.dtype}")
print(f" dtype - release_year: {df.release_year.dtype}")
print(f" dtype - rating: {df.rating.dtype}")
print(f" dtype - duration: {df.duration.dtype}")
print(f" dtype - listed_in: {df.listed_in.dtype}")
print(f" dtype - description: {df.description.dtype}")
# Out:
#  dtype - show_id: object
#  dtype - type: object
#  dtype - title: object
#  dtype - director: object
#  dtype - cast: object
#  dtype - country: object
#  dtype - date_added: object
#  dtype - release_year: int64
#  dtype - rating: object
#  dtype - duration: object
#  dtype - listed_in: object
#  dtype - description: object

# %%
df.dropna(axis="index", how="all")
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df["duration"].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
#to split duration column (integer+min/season)
l_num_dur=list() 
l_seas_min=list()
for i in df["duration"]:
    num_dur=int(i.split()[0]) #to get the integer value
    w_dur=i.split()[1] #to get the word Seasons/min
    l_num_dur.append(num_dur) #will add the numerical value of duration
    l_seas_min.append(w_dur) #will add either Seasons or min
df["Number duration"]=l_num_dur
df["Season/min"]=l_seas_min
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#plot the graph of the growth of tv shows and movies over the years
df_year_count=df.groupby(["release_year", "type"])["type"].count()
year_unique=df["release_year"].unique()
print(df_year_count)
plt.plot()
#idk vonc anem vor mi hat menak graphy gci tv showneri hamar mi hat movieneri, u ogtagorci county (columny anun chuni)
# Out:
# release_year  type
# 1925          TV Show      1
# 1942          Movie        2
# 1943          Movie        3
# 1944          Movie        3
# 1945          Movie        3
#                         ...
# 2019          TV Show    397
# 2020          Movie      517
#               TV Show    436
# 2021          Movie      277
#               TV Show    315
# Name: type, Length: 119, dtype: int64
# []

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
print(df.loc[df["rating"]=="74 min", "duration"])
print(df.loc[df["rating"]=="84 min", "duration"])
print(df.loc[df["rating"]=="66 min", "duration"])
#3 hat durationi arjeq Nan a exel, iskakan arjeqnery yngel ratingi mej
# Out:
# 5541    0 min
# Name: duration, dtype: object
# 5794    0 min
# Name: duration, dtype: object
# 5813    0 min
# Name: duration, dtype: object

# %%
df.loc[df["rating"]=="74 min", "duration"]="74 min"
df.loc[df["rating"]=="84 min", "duration"]="84 min"
df.loc[df["rating"]=="66 min", "duration"]="66 min"

# %%
print(df.loc[df["rating"]=="74 min", "duration"])
print(df.loc[df["rating"]=="84 min", "duration"])
print(df.loc[df["rating"]=="66 min", "duration"])
# Out:
# 5541    74 min
# Name: duration, dtype: object
# 5794    84 min
# Name: duration, dtype: object
# 5813    66 min
# Name: duration, dtype: object
